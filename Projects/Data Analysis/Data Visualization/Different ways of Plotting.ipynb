# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns ; sns.set()
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/LOGIN/Documents/Thinkful/kc_house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# # Choose one variable and plot that variable four different ways.

# %%
print('Line plots show data over time')
plt.plot(df.iloc[0:10]['price'])
plt.show()

print('Scatterplots show the relationship between two variables.')
plt.scatter(df['price'],df['bedrooms'])
plt.show()

print('Histograms show the distribution of the dataset and any outliers.')
plt.hist(df['price'])
plt.show()

print('Boxplots are used to compare groups and to identify differences in variance, as well as outliers.')
plt.boxplot(df['price'])
plt.show()
# Out:
# Line plots show data over time
# Scatterplots show the relationship between two variables.
# Histograms show the distribution of the dataset and any outliers.
# Boxplots are used to compare groups and to identify differences in variance, as well as outliers.

# %% [markdown]
# # Plot two continuous variables, and plot them three different ways

# %%
sns.set(style="whitegrid")

g = sns.factorplot(x="waterfront", y="price", hue="condition", data=df,
                   size=6, kind="point", palette="pastel",dodge=True,join=False)
g.despine(left=True)
g.set_ylabels("Prices")
g.set_xlabels("With or Without waterfront")
plt.title('Pointplot: Prices by conditons and waterfront')
plt.show()

# %%
sns.set(style="whitegrid")

ax = sns.boxplot(x='waterfront',y='price',hue='condition',data=df,palette='pastel')  

plt.title('Boxplot: Prices by conditons and waterfront')

sns.despine(offset=10, trim=True)
ax.set(xlabel='With or Without waterfront', ylabel='Prices')

plt.show()

# %%
sns.set(style="darkgrid")

barplot = sns.factorplot(x="waterfront", y="price", hue="condition", data=df,
                   size=6, kind="bar", palette="pastel")
barplot.despine(left=True)
barplot.set_ylabels("Prices")
barplot.set_xlabels("With or Without waterfront")
plt.title('Barplot: Prices by conditons and waterfron')
plt.show()

# %% [markdown]
# # Choose one continuous variable and one categorical variable, and plot them six different ways

# %%
df['renovated'] =np.where((df['sqft_lot']!= df['sqft_lot15'])|(df['sqft_living']!=df['sqft_living15']), 'Y', 'N')

# %%
sns.lmplot(x="sqft_lot15", y="price", hue="renovated", data=df)

# %%
df_loc = pd.DataFrame(df.groupby(['zipcode']).mean()['price'])
df_loc['zip'] = df_loc.index

# %%
df_loc["price"].plot(kind='bar',figsize = (18,10))

# %%
LocOfMillionHouse=df[df['price']>1000000]

# %%
LocOfMillionHouse2= pd.DataFrame(LocOfMillionHouse.groupby(['zipcode']).mean()['price'])
LocOfMillionHouse2['zip2'] = LocOfMillionHouse2.index

# %%
LocOfMillionHouse2["price"].plot(kind='bar',figsize = (18,10))

# %%
sns.set(style="whitegrid")

grade = sns.boxplot(x='grade',y='price',data=df,palette='pastel')  

plt.title('Boxplot: Prices by grade')

sns.despine(offset=10, trim=True)
ax.set(xlabel='grade', ylabel='Prices')

plt.show()

# %%
sns.set(style="whitegrid")

grade = sns.boxplot(x='condition',y='price',data=df,palette='pastel')  

plt.title('Boxplot: Prices by condition')

sns.despine(offset=10, trim=True)
ax.set(xlabel='Condition', ylabel='Prices')

plt.show()
