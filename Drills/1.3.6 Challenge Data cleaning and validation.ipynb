# %%
import pandas as pd
import numpy as np
import statistics
import matplotlib.pyplot as plt
import matplotlib as mpl
from collections import Counter
# %matplotlib inline

# %%
# file_encoding = 'utf8'
# input_encoded = open('WELLCOME_APCspend2013_forThinkful.csv', encoding=file_encoding, errors = 'ignore')
# pd.read_csv(input_encoded)

# %%
#Read the CSV file, we need the extra encoding part otherwise python won't read it correctly
df = pd.read_csv('F:/Thinkful/Drills/WELLCOME_APCspend2013_forThinkful.csv',encoding='ISO-8859-1',low_memory = False)

# %%
df
# Out:
#                             PMID/PMCID  \
# 0                                  NaN
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21                                 NaN
# 22            PMCID:\n    PMC3656742\n
# ...

# %%
#Remove the space in column names in order to use the function unique()
df.columns = ['PMID/PMCID','Publisher','JournalTitle','ArticleTitle','Cost']

# %%
#Drop NAN value
df = df.dropna()

# %%
pd.options.mode.chained_assignment = None

# %%
#Convert every letter in column 'JournalTitle' to lower case for the ease of manipulation and visualization
df['JournalTitle'] = df.loc[:,'JournalTitle'].str.lower()

# %%
df.head()
# Out:
#               PMID/PMCID Publisher                    JournalTitle  \
# 1             PMC3679557       ACS               biomacromolecules
# 2  23043264  PMC3506128        ACS                      j med chem
# 3    23438330 PMC3646402       ACS                      j med chem
# 4   23438216 PMC3601604        ACS                      j org chem
# 5             PMC3579457       ACS  journal of medicinal chemistry
#
#                                         ArticleTitle      Cost
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88
# 5  Comparative Structural and Functional Studies ...  £2392.20

# %%
df['JournalTitle']= df['JournalTitle'].str.strip()

# %%
list_of_Titles = [
    '\n',
    'biologicial',
    'behavioural',
    'molecular pain',
    'and',
    'british journal of the history of science',
    'american journal for clinical nutrition',
    'behavior',
    'bioohysica',
    'neurosciences',
    'studies in history and philosophy of science part c: studies in history and philosophy of biological and biomedical sciences',
    'haematologica/the haematology journal',
    'acta crystallographica section d: biological crystallography',
    'acta crystallographica, section d',
    'acta crystallography d',
    'acta crystallographica section d,  biological crystallography ',
    'acta crystallographica section f: structural biology and crystallization communications',
    'epigentics',
    'experiements',
    'proceedings of the national academy of sciences of the united states of america ',
    'proceedings of the national academy of sciences ',
    'proceddings of the national academy of sciences of usa',
    '(',
    ')',
    'cell death and disease ',
    'embo journal',
    'the embo journal',
    'american jnl epidemiology',
    'clinical infectious diseases online',
    'int j epidemiol',
    'inyernational',
    'biinformatics',
    'brain online',
    'nephrology dialysis transplantation',
    'acids',
    'j infect dis',
    'pnas usa',
    'proc natl acad sci u s a.',
    'proceedings of the national academy of sciences of the usa',
    'journals',
    'proceedings of the national academy of sciences (pnas)',
    'plos medicine journal',
    'negected',
    'public library of science one',
    'britsh',
    'the british journal of psychiatry',
    '\xa0 ',
    'pmedicine-d-12-03130',
    'pone-d12-17947',
    'journal of the royal society, interface',
    'philos trans r soc london b biol sci',
    'proceedings of the royal society b: biological sciences',
    'proceedings of royal society',
    'proceedings b',
    'journal of microbiology',
    'the journal of neuroscience',
    'acta neuropathol',
    'cellular and molecular cell sciences',
    'psychiatty',
    'journal of autism and development disorders',
    'epidemiol',
    '+',
    'rstb 2012.0145',
    'british journal of clinical pharmacology',
    '-',
    'human mutation: variation, informatics, and disease',
    'dev. world bioeth',
    'aids uk',
    'aids journal',
    'jaids',
    'journal of acquired immune deficiency syndroms (jaids)',
    'ophthalmology',
    'neuropathologicaogica',
    'acta crystallographica section f: structural biology & crystallization communications',
    'bioethicsneuroscience',
    'am j bioeth',
    'am j trop med hyg',
    'medical geneticspart a',
    'antimicobial',
    'agfents',
    'angew chems int ed',
    'angew&e chemie',
    'biochem soc trans',
    'biochem journal',
    'bioinformatics online',
    'blood journal 2012',
    'genomics.',
    'bmc  public health',
    'jounal ',
    'brt jnl clinical pharmacology',
    'cell journal',
    'cell press  cell reports',
    'cellular & molecular cell sciences',
    'clinicla infectious disease',
    'curr biol.',
    'dev world bioeth. ',
    'dev world bioeth ',
    'development cell ',
    'eur j immunol ',
    'european neuropsychopharmacology ',
    'febs j. ',
    'faseb journal',
    'epidemiologyogy',
    'health: an interdisciplinary journal for the social study of health, illness & medicine',
    'human mol geneticsonline',
    'human mutation: variation, informatics, & disease',
    'int journal for parasitology',
    'j biol chem.',
    'j biol chemistry',
    'jnl biological chemistry',
    'j cell sci.',
    'j clin microbiol',
    'j immunol',
    'j immunol ',
    'j med chem',
    'j med chem.',
    'j mol biol',
    'journal of aids',
    'journal of autism & development disorders',
    'journal of virology',
    'marten child nutr',
    'mbio',
    'microbes infect',
    'mol bio',
    'mol biol & evolution',
    'molecluar',
    'nephrology dialysis and transplantation',
    'neuroepidemiologyogy',
    'philosophical transactions b',
    'plosone',
    'pnas proceedings of the national academy of sciences of the united states of americaof the united states of americaof the united states of america',
    'proceedings of the national academy of sciences',
    'proceedings of the national academy of sciences of the united states of america',
    'proceedings of the national academy of sciences of the united states of americaof the united states of america',
    'proceedings of the national academy of sciences of the united states of americaof the united states of americaof the united states of america',
    'proceedings of the national academy of sciences of the united states of americaof the united states of americaof the usa',
    'scientific reports1100861b',
    'social psychiatry & psychiatric epidemiologyogy',
    'studies in history & philosophy of science part c: studies in history & philosophy of biological & biomedical sciences',
    'the americal journal of human genetics',
    'the faseb journal',
    'thorax an international journal for respiratory medicine',
    'trop med int health',
    'virology journal',
    'epidemology'
]

list_of_NewTitles = [
    "",
    "biological",
    "behavioral",
    "molecular brain",
    "&",
    "british journal for the history of science",
    "american journal of clinical nutrition",
    "behaviour",
    "biophysica",
    "neuroscience",
    "studies in history and philosophy of science part c",
    "haematologica",
    "acta d",
    "acta d",
    "acta d",
    "acta d",
    "acta f",
    "epigenetics",
    "experiments",
    "proceedings of the national academy of sciences of the united states of america",
    "proceedings of the national academy of sciences of the united states of america",
    "proceedings of the national academy of sciences of the united states of america",
    "",
    "",
    "cell death & disease",
    "embo",
    "embo",
    "american journal of epidemiology",
    "clinical infectious diseases",
    "international journal of epidemiology",
    "international",
    "bioinformatics",
    "brain",
    "nephrology dialysis and transplantation",
    "acid",
    "the journal of infectious diseases",
    "proceedings of the national academy of sciences of the united states of america",
    "proceedings of the national academy of sciences of the united states of america",
    "proceedings of the national academy of sciences of the united states of america",
    "journal",
    "proceedings of the national academy of sciences of the united states of america",
    "plos medicine",
    "neglected",
    "public library of science",
    "british",
    "british journal of psychiatry",
    "",
    "plos medicine",
    "plos one",
    "journal of the royal society interface",
    "philosophical transactions b",
    "proceedings of the royal society",
    "proceedings of the royal society",
    "proceedings of the royal society",
    'microbiology',
    "journal of neuroscience",
    "acta neuropathologica",
    "cellular and molecular life sciences",
    "psychiatry",
    "journal of autism and developmental disorders",
    "epidemiology",
    "&",
    "rstb",
    "british journal of pharmacology",
    "",
    "human mutation",
    "dev world bioeth",
    "aids",
    "aids",
    "aids",
    "journal of acquired immune deficiency syndromes",
    "opthalmology",
    "neuropathologica",
    "acta crystallographica section f",
    "bioethics",
    "bioethics",
    "american journal of tropical medicine & hygiene",
    "medical genetics",
    "antimicrobial",
    "agents",
    "angew&te chemie international edition",
    "angewandte chemie",
    "biochemical society transactions",
    "biochemical journal",
    "bioinformatics",
    "blood",
    "genomics",
    "bmc public health",
    "journal",
    "british journal of pharmacology",
    "cell",
    "cell reports",
    "cellular & molecular life sciences",
    "clinical infectious diseases",
    "current biology",
    "developing world bioethics",
    "developing world bioethics",
    "developmental cell",
    "european journal of immunology",
    "european journal of clinical pharmacology",
    "febs journal",
    "febs journal",
    "epidemology",
    "health",
    "human molecular genetics online",
    "human mutation",
    "international journal of parasitology",
    "journal biological chemistry",
    "journal biological chemistry",
    "journal biological chemistry",
    "journal of cell science",
    "journal of clinical microbiology",
    "journal of immunology",
    "journal of immunology",
    "journal of medicinal chemistry",
    "journal of medicinal chemistry",
    "journal of molecular biology",
    "journal of acquired immune deficiency syndromes",
    "journal of autism & developmental disorders",
    'virology',
    "maternal & child nutrition",
    "matrix biology",
    "microbes & infection",
    "molecular biology",
    "molecular biology & evolution",
    "molecular",
    "nephrology dialysis & transplantation",
    "neuroepidemiology",
    "philosophical transactions of the royal society of london. series b, biological sciences",
    "plos one",
    "pnas",
    "pnas",
    "pnas",
    "pnas",
    "pnas",
    "pnas",
    "scientific reports",
    "social psychiatry & psychiatric epidemiology",
    "studies in history & philosophy of science part c",
    "the american journal of human genetics",
    "the febs journal",
    "thorax",
    "tropical medicine & international health",
    "virology",
    "epidemiology"

]

# %%
newlist=zip(list_of_Titles,list_of_NewTitles)

# %%
for titlepair in newlist:
    df['JournalTitle'] = df['JournalTitle'].str.replace(titlepair[0],titlepair[1])

# %%
#Start cleaning the data by replacing any unwanted value to either nothing or some reasonable value

# df['JournalTitle'] = df['JournalTitle'].str.replace('\n', "")
# df['JournalTitle'] = df['JournalTitle'].str.replace('biologicial', "biological")
# df['JournalTitle'] = df['JournalTitle'].str.replace('behavioural', "behavioral")
# df['JournalTitle'] = df['JournalTitle'].str.replace('molecular pain', "molecular brain")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('trials ', "trials")
# df['JournalTitle'] = df['JournalTitle'].str.replace('and', "&")
# df['JournalTitle'] = df['JournalTitle'].str.replace('british journal of the history of science', "british journal for the history of science")
# df['JournalTitle'] = df['JournalTitle'].str.replace('american journal for clinical nutrition', "american journal of clinical nutrition")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('genetics ', "genetics")
# df['JournalTitle'] = df['JournalTitle'].str.replace('behavior', "behaviour")
# df['JournalTitle'] = df['JournalTitle'].str.replace('bioohysica', "biophysica")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('journal of affective disorders ', "journal of affective disorders")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('neuropharmacology ', "neuropharmacology")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('neuroscience ', "neuroscience")
# df['JournalTitle'] = df['JournalTitle'].str.replace('studies in history and philosophy of science part c: studies in history and philosophy of biological and biomedical sciences', "studies in history and philosophy of science part c")
# df['JournalTitle'] = df['JournalTitle'].str.replace('neurosciences', "neuroscience")
# df['JournalTitle'] = df['JournalTitle'].str.replace('haematologica/the haematology journal', "haematologica")
# df['JournalTitle'] = df['JournalTitle'].str.replace('acta crystallographica section d: biological crystallography', "acta d")
# df['JournalTitle'] = df['JournalTitle'].str.replace('acta crystallographica, section d', "acta d")
# df['JournalTitle'] = df['JournalTitle'].str.replace('acta crystallography d', "acta d")
# df['JournalTitle'] = df['JournalTitle'].str.replace('acta crystallographica section d,  biological crystallography ', "acta d")
# df['JournalTitle'] = df['JournalTitle'].str.replace('acta crystallographica section f: structural biology and crystallization communications', "acta f")
# df['JournalTitle'] = df['JournalTitle'].str.replace('epigentics', "epigenetics")
# df['JournalTitle'] = df['JournalTitle'].str.replace('experiements', "experiments")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('journal of visualized experiments ', "journal of visualized experiments")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings of the national academy of sciences of the united states of america ', "proceedings of the national academy of sciences of the united states of america")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings of the national academy of sciences ', "proceedings of the national academy of sciences of the united states of america")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceddings of the national academy of sciences of usa', "proceedings of the national academy of sciences of the united states of america")
# df['JournalTitle'] = df['JournalTitle'].str.replace('(', "")
# df['JournalTitle'] = df['JournalTitle'].str.replace(')', "")
# df['JournalTitle'] = df['JournalTitle'].str.replace('cell death and disease ', "cell death & disease")
# df['JournalTitle'] = df['JournalTitle'].str.replace('embo journal', "embo")
# df['JournalTitle'] = df['JournalTitle'].str.replace('the embo journal', "embo")
# df['JournalTitle'] = df['JournalTitle'].str.replace('american jnl epidemiology', "american journal of epidemiology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('clinical infectious diseases online', "clinical infectious diseases")
# df['JournalTitle'] = df['JournalTitle'].str.replace('int j epidemiol', "international journal of epidemiology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('inyernational', "international")
# df['JournalTitle'] = df['JournalTitle'].str.replace('biinformatics', "bioinformatics")
# df['JournalTitle'] = df['JournalTitle'].str.replace('brain online', "brain")
# df['JournalTitle'] = df['JournalTitle'].str.replace('nephrology dialysis transplantation', "nephrology dialysis and transplantation")
# df['JournalTitle'] = df['JournalTitle'].str.replace('acids', "acid")
# df['JournalTitle'] = df['JournalTitle'].str.replace('j infect dis', "the journal of infectious diseases")
# df['JournalTitle'] = df['JournalTitle'].str.replace('pnas usa', "proceedings of the national academy of sciences of the united states of america")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proc natl acad sci u s a.', "proceedings of the national academy of sciences of the united states of america")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings of the national academy of sciences of the usa', "proceedings of the national academy of sciences of the united states of america")
# df['JournalTitle'] = df['JournalTitle'].str.replace('journals', "journal")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings of the national academy of sciences (pnas)', "proceedings of the national academy of sciences of the united states of america")
# df['JournalTitle'] = df['JournalTitle'].str.replace('plos medicine journal', "plos medicine")
# df['JournalTitle'] = df['JournalTitle'].str.replace('negected', "neglected")
# df['JournalTitle'] = df['JournalTitle'].str.replace('public library of science one', "public library of science")
# df['JournalTitle'] = df['JournalTitle'].str.replace('britsh', "british")
# df['JournalTitle'] = df['JournalTitle'].str.replace('the british journal of psychiatry', "british journal of psychiatry")
# df['JournalTitle'] = df['JournalTitle'].str.replace('\xa0 ', "")
# df['JournalTitle'] = df['JournalTitle'].str.replace('pmedicine-d-12-03130', "plos medicine")
# df['JournalTitle'] = df['JournalTitle'].str.replace('pone-d12-17947', "plos one")
# df['JournalTitle'] = df['JournalTitle'].str.replace('journal of the royal society, interface', "journal of the royal society interface")
# df['JournalTitle'] = df['JournalTitle'].str.replace('philos trans r soc london b biol sci', "philosophical transactions b")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings of the royal society b: biological sciences', "proceedings of the royal society")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings of royal society', "proceedings of the royal society")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings b', "proceedings of the royal society")
# df['JournalTitle'] = df['JournalTitle'].str.replace('journal of microbiology', 'microbiology')
# df['JournalTitle'] = df['JournalTitle'].str.replace('the journal of neuroscience', "journal of neuroscience")
# df['JournalTitle'] = df['JournalTitle'].str.replace('acta neuropathol', "acta neuropathologica")
# df['JournalTitle'] = df['JournalTitle'].str.replace('cellular and molecular cell sciences', "cellular and molecular life sciences")
# df['JournalTitle'] = df['JournalTitle'].str.replace('psychiatty', "psychiatry")
# df['JournalTitle'] = df['JournalTitle'].str.replace('journal of autism and development disorders', "journal of autism and developmental disorders'")
# df['JournalTitle'] = df['JournalTitle'].str.replace('epidemiol', "epidemiology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('+', "&")
# df['JournalTitle'] = df['JournalTitle'].str.replace('rstb 2012.0145', "rstb")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('annals of neurology ', "annals of neurology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('british journal of clinical pharmacology', "british journal of pharmacology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('-', "")
# df['JournalTitle'] = df['JournalTitle'].str.replace('human mutation: variation, informatics, and disease', "human mutation")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('journal of neurochemistry ', "journal of neurochemistry")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('magnetic resonance in medicine ', "magnetic resonance in medicine")
# df['JournalTitle'] = df['JournalTitle'].str.replace('dev. world bioeth', "dev world bioeth")
# df['JournalTitle'] = df['JournalTitle'].str.replace('aids uk', "aids")
# df['JournalTitle'] = df['JournalTitle'].str.replace('aids journal', "aids")
# df['JournalTitle'] = df['JournalTitle'].str.replace('jaids', "aids")
# df['JournalTitle'] = df['JournalTitle'].str.replace('journal of acquired immune deficiency syndroms (jaids)', "journal of acquired immune deficiency syndromes")

# %%
# df['JournalTitle'] = df['JournalTitle'].str.replace('ophthalmology', "opthalmology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('neuropathologicaogica', "neuropathologica")
# df['JournalTitle'] = df['JournalTitle'].str.replace('acta crystallographica section f: structural biology & crystallization communications', "acta crystallographica section f")
# # df['JournalTitle'] = df['JournalTitle'].str.replace('acta f', "acta crystallographica section f")
# df['JournalTitle'] = df['JournalTitle'].str.replace('bioethicsneuroscience', "bioethics")
# df['JournalTitle'] = df['JournalTitle'].str.replace('am j bioeth', "bioethics")
# df['JournalTitle'] = df['JournalTitle'].str.replace('am j trop med hyg', "american journal of tropical medicine & hygiene")
# df['JournalTitle'] = df['JournalTitle'].str.replace('medical geneticspart a', "medical genetics")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('american journal of preventive medicine ', "american journal of preventive medicine")
# df['JournalTitle'] = df['JournalTitle'].str.replace('antimicobial', "antimicrobial")
# df['JournalTitle'] = df['JournalTitle'].str.replace('agfents', "agents")
# df['JournalTitle'] = df['JournalTitle'].str.replace('angew chems int ed', "angew&te chemie international edition")
# df['JournalTitle'] = df['JournalTitle'].str.replace('angew&e chemie', "angewandte chemie")
# df['JournalTitle'] = df['JournalTitle'].str.replace('biochem soc trans', "biochemical society transactions")
# df['JournalTitle'] = df['JournalTitle'].str.replace('biochem journal', "biochemical journal")
# df['JournalTitle'] = df['JournalTitle'].str.replace('bioinformatics online', "bioinformatics")
# df['JournalTitle'] = df['JournalTitle'].str.replace('blood journal 2012', "blood")
# df['JournalTitle'] = df['JournalTitle'].str.replace('genomics.', "genomics")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('bmc infectious diseases ', "bmc infectious diseases")
# df['JournalTitle'] = df['JournalTitle'].str.replace('bmc  public health', "bmc public health")
# df['JournalTitle'] = df['JournalTitle'].str.replace('jounal ', "journal")
# df['JournalTitle'] = df['JournalTitle'].str.replace('brt jnl clinical pharmacology', "british journal of pharmacology")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('cell death & disease ', "cell death & disease")
# df['JournalTitle'] = df['JournalTitle'].str.replace('cell journal', "cell")
# df['JournalTitle'] = df['JournalTitle'].str.replace('cell press  cell reports', "cell reports")
# df['JournalTitle'] = df['JournalTitle'].str.replace('cellular & molecular cell sciences', "cellular & molecular life sciences")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('child: care, heath & development ', "child: care, health development")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('clinical infectious diseases ', "clinical infectious diseases")
# df['JournalTitle'] = df['JournalTitle'].str.replace('clinicla infectious disease', "clinical infectious diseases")
# df['JournalTitle'] = df['JournalTitle'].str.replace('curr biol.', "current biology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('dev world bioeth. ', "developing world bioethics")
# df['JournalTitle'] = df['JournalTitle'].str.replace('dev world bioeth ', "developing world bioethics")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('development ', "development")
# df['JournalTitle'] = df['JournalTitle'].str.replace('development cell ', "developmental cell")
# df['JournalTitle'] = df['JournalTitle'].str.replace('eur j immunol ', "european journal of immunology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('european neuropsychopharmacology ', "european journal of clinical pharmacology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('febs j. ', "febs journal")
# df['JournalTitle'] = df['JournalTitle'].str.replace('faseb journal', "febs journal")
# df['JournalTitle'] = df['JournalTitle'].str.replace('epidemiologyogy', "epidemology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('health: an interdisciplinary journal for the social study of health, illness & medicine', "health")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('health  ', "health")
# df['JournalTitle'] = df['JournalTitle'].str.replace('human mol geneticsonline', "human molecular geneticsonline")
# df['JournalTitle'] = df['JournalTitle'].str.replace('human mutation: variation, informatics, & disease', "human mutation")
# df['JournalTitle'] = df['JournalTitle'].str.replace('int journal for parasitology', "international journal of parasitology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('j biol chem.', "journal biological chemistry")
# df['JournalTitle'] = df['JournalTitle'].str.replace('j biol chemistry', "journal biological chemistry")
# df['JournalTitle'] = df['JournalTitle'].str.replace('jnl biological chemistry', "journal biological chemistry")
# df['JournalTitle'] = df['JournalTitle'].str.replace('j cell sci.', "journal of cell science")
# df['JournalTitle'] = df['JournalTitle'].str.replace('j clin microbiol', "journal of clinical microbiology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('j immunol', "journal of immunology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('j immunol ', "journal of immunology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('j med chem', "journal of medicinal chemistry")
# df['JournalTitle'] = df['JournalTitle'].str.replace('j med chem.', "journal of medicinal chemistry")
# df['JournalTitle'] = df['JournalTitle'].str.replace('j mol biol', "journal of molecular biology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('journal of aids', "journal of acquired immune deficiency syndromes")
# df['JournalTitle'] = df['JournalTitle'].str.replace('journal of autism & development disorders', "journal of autism & developmental disorders")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('journal of clinical microbiology ', "journal of clinical microbiology")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('journal of medical virology ', "journal of medical virology")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('journal of medicinal chemistry ', "journal of medicinal chemistry")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('journal of neurology, neurosurgery & psychiatry ', "journal of neurology, neurosurgery & psychiatry")
# df['JournalTitle'] = df['JournalTitle'].str.replace('journal of virology', 'virology')
# #df['JournalTitle'] = df['JournalTitle'].str.replace('malaria journal ', "malaria journal")
# df['JournalTitle'] = df['JournalTitle'].str.replace('marten child nutr', "maternal & child nutrition")
# df['JournalTitle'] = df['JournalTitle'].str.replace('mbio', "matrix biology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('microbes infect', "microbes & infection")
# df['JournalTitle'] = df['JournalTitle'].str.replace('mol bio', "molecular biology")
# df['JournalTitle'] = df['JournalTitle'].str.replace('mol biol & evolution', "molecular biology & evolution")
# df['JournalTitle'] = df['JournalTitle'].str.replace('molecluar', "molecular")
# df['JournalTitle'] = df['JournalTitle'].str.replace('nephrology dialysis and transplantation', "nephrology dialysis & transplantation")
# df['JournalTitle'] = df['JournalTitle'].str.replace('neuroepidemiologyogy', "neuroepidemiology")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('nucleic acid research ', "nucleic acid research")
# df['JournalTitle'] = df['JournalTitle'].str.replace('philosophical transactions b', "philosophical transactions of the royal society of london. series b, biological sciences")
# df['JournalTitle'] = df['JournalTitle'].str.replace('plosone', "plos one")
# df['JournalTitle'] = df['JournalTitle'].str.replace('pnas proceedings of the national academy of sciences of the united states of americaof the united states of americaof the united states of america', "pnas")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings of the national academy of sciences', "pnas")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings of the national academy of sciences of the united states of america', "pnas")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings of the national academy of sciences of the united states of americaof the united states of america', "pnas")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings of the national academy of sciences of the united states of americaof the united states of americaof the united states of america', "pnas")
# df['JournalTitle'] = df['JournalTitle'].str.replace('proceedings of the national academy of sciences of the united states of americaof the united states of americaof the usa', "pnas")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('schizophrenia bulletin ', "schizophrenia bulletin")
# df['JournalTitle'] = df['JournalTitle'].str.replace('scientific reports1100861b', "scientific reports")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('sexually transmitted infections                         ', "sexually transmitted infections")
# df['JournalTitle'] = df['JournalTitle'].str.replace('social psychiatry & psychiatric epidemiologyogy', "social psychiatry & psychiatric epidemiology")
# #df['JournalTitle'] = df['JournalTitle'].str.replace('social science & medicine ', "social science & medicine")
# df['JournalTitle'] = df['JournalTitle'].str.replace('studies in history & philosophy of science part c: studies in history & philosophy of biological & biomedical sciences', "studies in history & philosophy of science part c")
# df['JournalTitle'] = df['JournalTitle'].str.replace('the americal journal of human genetics', "the american journal of human genetics")
# df['JournalTitle'] = df['JournalTitle'].str.replace('the faseb journal', "the febs journal")
# df['JournalTitle'] = df['JournalTitle'].str.replace('thorax an international journal for respiratory medicine', "thorax")
# df['JournalTitle'] = df['JournalTitle'].str.replace('trop med int health', "tropical medicine & international health")
# df['JournalTitle'] = df['JournalTitle'].str.replace('virology journal', "virology")

# %%
#df['JournalTitle'] = df['JournalTitle'].str.replace('epidemology', "epidemiology")

# %%
df['JournalTitle'] = df['JournalTitle'].str.replace('pnas of the united states of americaof the united states of america', "pnas")

# %%
df['JournalTitle'] = df['JournalTitle'].str.replace('pnaspnas', "pnas")
df['JournalTitle'] = df['JournalTitle'].str.replace('pnasof the usa', "pnas")
df['JournalTitle'] = df['JournalTitle'].str.replace('pnasof the united states of america', "pnas")
df['JournalTitle'] = df['JournalTitle'].str.replace('pnas of the united states of america', "pnas")

# %%
df['JournalTitle'] = df['JournalTitle'].str.replace('molecular biologyl & evolution', "molecular biology & evolution")
df['JournalTitle'] = df['JournalTitle'].str.replace('journal of medicinal chemistry.', "journal of medicinal chemistry")
df['JournalTitle'] = df['JournalTitle'].str.replace('journal of immunology ', "journal of immunology")
df['JournalTitle'] = df['JournalTitle'].str.replace('journal of autism & developmentdisorders', "journal of autism & developmental disorders")
df['JournalTitle'] = df['JournalTitle'].str.replace('journal of acquired immune deficiency syndroms aids', "aids")
df['JournalTitle'] = df['JournalTitle'].str.replace('journal biological chemistrystry', "journal biological chemistry")
df['JournalTitle'] = df['JournalTitle'].str.replace('dev world bioeth.', "dev world bioeth")
df['JournalTitle'] = df['JournalTitle'].str.replace('cell death differentiation', "cell death & differentiation")
df['JournalTitle'] = df['JournalTitle'].str.replace('journal of acquired immune deficiency syndromes', "aids")

# %%
df['JournalTitle'] = df['JournalTitle'].str.replace('journal of virol', "virology")

# %%
df['JournalTitle'] = df['JournalTitle'].str.replace('virologyogical methods', "journal of virological methos")

# %%
#Identify all the unique value in the column 'JournalTitle' and make them into a list and sort it. This way we can quick identify any duplications or 
#abbreviations

Journal = list(df.JournalTitle.unique())
#Journal.sort(reverse=False)
Journal.sort()
Journal
# Out:
# ['academy of nutrition & dietetics',
#  'acs chemical biology',
#  'acs chemical neuroscience',
#  'acs nano',
#  'acta crystallographica section d,  biological crystallography',
#  'acta crystallographica section f',
#  'acta d',
#  'acta dermato venereologica',
#  'acta diabetologica',
#  'acta f',
#  'acta neuropathologica',
#  'acta opthalmologica',
#  'acta physiol',
#  'addiction',
#  'age',
#  'age & ageing',
#  'aging cell',
#  'aids',
#  'aids behav',
#  'aids care',
#  'aids of acquired immune deficiency syndromes',
#  'aids research & therapy',
#  'alcohol & alcoholism',
#  'alimentrary pharmacology & therapeutics',
#  'americal journal of psychiatry',
#  'american chemical society',
#  'american journal of bioethics',
#  'american journal of clinical nutrition',
#  'american journal of epidemiology',
#  'american journal of geriatric psychiatry',
#  'american journal of human genetics',
#  'american journal of medical genetics',
# ...

# %%
#Make the list into a dictionary with number of occurence of each unique value

d = dict(Counter(df['JournalTitle']))

# %%
#Print the sorted dictionary from highest to lowest to see top 5 popular journals.

sorted(d.items(), key=lambda x: x[1],reverse=True)
# Out:
# [('plos one', 198),
#  ('journal of biological chemistry', 52),
#  ('pnas', 34),
#  ('neuroimage', 28),
#  ('nucleic acid research', 28),
#  ('plos pathogens', 24),
#  ('plos genetics', 23),
#  ('plos neglected tropical diseases', 21),
#  ('nature communications', 19),
#  ('human molecular genetics', 17),
#  ('brain', 15),
#  ('journal of medicinal chemistry', 13),
#  ('biochemical journal', 13),
#  ('bmc public health', 13),
#  ('movement disorders', 13),
#  ('virology', 12),
#  ('journal of neuroscience', 12),
#  ('proceedings of the royal society', 12),
#  ('current biology', 11),
#  ('journal of general virology', 11),
#  ('journal biological chemistry', 10),
#  ('malaria journal', 10),
#  ('cell reports', 10),
#  ('febs journal', 10),
#  ('bmj open', 9),
#  ('developmental cell', 9),
#  ('aids', 9),
#  ('journal of clinical endocrinology & metabolism', 8),
#  ('journal of cell science', 8),
#  ('development', 8),
#  ('journal of structural biology', 8),
# ...

# %%
#Remove the currency symbol
df['Cost'] = df['Cost'].str.replace('£','')

# %%
#Let's see what type of the number under column 'Cost'
type(df.at[5,'Cost'])
# Out:
# str

# %%
#Because it it string, so we need to convert it into numeric

df['Cost'] = pd.to_numeric(df['Cost'], errors='coerce')

# %%
df = df[df.Cost !=999999.00]

# %%
#In the last step, we used errors='coerce', so any value that is not be able to convert to numeric had been converted to NAN
#So we need to drop any new nan value again. Just in case.

df.dropna()
# Out:
#                             PMID/PMCID  \
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 22            PMCID:\n    PMC3656742\n
# 23                      PMCID: 3584654
# 24                 22971149 PMC3466778
# ...

# %%
avg = df.groupby(['JournalTitle']).mean()['Cost']

# %%
median = df.groupby(['JournalTitle']).median()['Cost']

# %%
std = df.groupby(['JournalTitle']).std(ddof=0)['Cost']

# %%
avg = pd.DataFrame(avg)
avg.head()
# Out:
#                                                         Cost
# JournalTitle
# academy of nutrition & dietetics                    2379.540
# acs chemical biology                                1535.965
# acs chemical neuroscience                           1186.800
# acs nano                                             668.140
# acta crystallographica section d,  biological c...   771.420

# %%
median = pd.DataFrame(median)
median.head()
# Out:
#                                                         Cost
# JournalTitle
# academy of nutrition & dietetics                    2379.540
# acs chemical biology                                1294.685
# acs chemical neuroscience                           1186.800
# acs nano                                             668.140
# acta crystallographica section d,  biological c...   771.420

# %%
std = pd.DataFrame(std)
std.head()
# Out:
#                                                           Cost
# JournalTitle
# academy of nutrition & dietetics                      0.000000
# acs chemical biology                                433.593733
# acs chemical neuroscience                             0.000000
# acs nano                                             25.250000
# acta crystallographica section d,  biological c...    0.000000

# %%
df['SubjectArea1'] = np.where((df['JournalTitle'].str.contains('chem')),'Chem','')

# %%
df['SubjectArea2'] = np.where((df['JournalTitle'].str.contains('immu')),'Immunology','')

# %%
df
# Out:
#                             PMID/PMCID  \
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 22            PMCID:\n    PMC3656742\n
# 23                      PMCID: 3584654
# 24                 22971149 PMC3466778
# ...

# %%
df.JournalTitle.unique()
# Out:
# array(['biomacromolecules', 'journal of medicinal chemistry',
#        'j org chem', 'journal of proteome research', 'mol pharm',
#        'acs chemical biology',
#        'journal of chemical information & modeling', 'biochemistry',
#        'gastroenterology', 'journal of biological chemistry',
#        'journal of immunology', 'acs chemical neuroscience', 'acs nano',
#        'american chemical society', 'analytical chemistry',
#        'bioconjugate chemistry',
#        'journal of the american chemical society', 'chest',
#        'journal of neurophysiology', 'journal of physiology',
#        'the journal of neurophysiology', 'americal journal of psychiatry',
#        'behavioural neuroscience', 'emotion', 'health psychology',
#        'journal of abnormal psychology',
#        'journal of consulting & clinical psychology',
#        'journal of experimental psychology:  animal behaviour process',
#        'journal of experimental psychology: human perception & performance',
# ...
